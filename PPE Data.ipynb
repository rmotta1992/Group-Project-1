# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from sklearn import datasets 
from scipy.stats import linregress

base_data = "resources/vodkadata.csv"

ppe_data = pd.read_csv(base_data)

ppe_data.head(30)
# Out:
# /Users/ezeavila/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Unnamed: 0     Unnamed: 1   Unnamed: 2       Unnamed: 3  \
# 0        Total US  BC DEPARTMENT  BC CATEGORY  BC SUB CATEGORY
# 1   Total US xAOC        ALCOHOL        VODKA            VODKA
# 2   Total US xAOC        ALCOHOL        VODKA            VODKA
# 3   Total US xAOC        ALCOHOL        VODKA            VODKA
# 4   Total US xAOC        ALCOHOL        VODKA            VODKA
# 5   Total US xAOC        ALCOHOL        VODKA            VODKA
# 6   Total US xAOC        ALCOHOL        VODKA            VODKA
# 7   Total US xAOC        ALCOHOL        VODKA            VODKA
# ...
