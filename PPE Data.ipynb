# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from sklearn import datasets 
from scipy.stats import linregress

base_data = "resources/ppedata_updated.csv"

ppe_data_df = pd.read_csv(base_data)

ppe_data_df.head()
# Out:
#         Total US         BC DEPARTMENT     BC CATEGORY  \
# 0  Total US xAOC  HEALTH & BEAUTY CARE  HAND SANITIZER
# 1  Total US xAOC  HEALTH & BEAUTY CARE  HAND SANITIZER
# 2  Total US xAOC  HEALTH & BEAUTY CARE  HAND SANITIZER
# 3  Total US xAOC  HEALTH & BEAUTY CARE  HAND SANITIZER
# 4  Total US xAOC  HEALTH & BEAUTY CARE  HAND SANITIZER
#
#                BRAND OWNER HIGH              BRAND HIGH  \
# 0            1 INDICO CHILD LLC               DR. HOBBS
# 1            1 INDICO CHILD LLC               DR. HOBBS
# 2  21ST CENTURY HEALTH CARE INC            WHOLE HEALTH
# 3  21ST CENTURY HEALTH CARE INC            WHOLE HEALTH
# 4         28 MILE VODKA COMPANY  28 MILE DISTILLING CO.
#
#                 BRAND LOW       PACK SIZE     PRODUCT SIZE           UPC  \
# 0               DR. HOBBS  NOT APPLICABLE          1 COUNT  5.096788e+09
# 1               DR. HOBBS  NOT APPLICABLE          1 COUNT  5.096788e+09
# 2            WHOLE HEALTH         2 COUNT  1.8 FLUID OUNCE  8.401091e+10
# 3            WHOLE HEALTH         3 COUNT   .5 FLUID OUNCE  3.225113e+09
# 4  28 MILE DISTILLING CO.  NOT APPLICABLE   16 FLUID OUNCE  8.600040e+10
#
#                             LONG PRODUCT DESCRIPTION  ...  \
# 0              DR HBS HND SNTZ LQD 1 CT 005096787734  ...
# 1              DR HBS HND SNTZ LQD 1 CT 005096787735  ...
# 2  WHL HLT HND SNTZ LQD BTL 1.8 FL OZ HSHL DCRT A...  ...
# 3  WHL HLT HND SNTZ LVND AL RGLR CRDD 1.5 FL OZ 0...  ...
# 4  28 ML DST CO HND SNTZ LQD SCNT BTL 16 FL OZ 08...  ...
#
#   Numerical Distribution 1 W/E 07/11/20 Numerical Distribution 1 W/E 07/18/20  \
# 0                                   0.0                                   0.0
# 1                                   0.7                                   0.5
# 2                                   0.0                                   0.0
# 3                                   NaN                                   NaN
# 4                                   0.1                                   0.1
#
#   Numerical Distribution 1 W/E 07/25/20 Numerical Distribution 1 W/E 08/01/20  \
# 0                                   0.0                                   0.0
# 1                                   0.5                                   0.5
# 2                                   0.0                                   0.0
# 3                                   NaN                                   NaN
# 4                                   0.1                                   0.1
#
#   Numerical Distribution 1 W/E 08/08/20 Numerical Distribution 1 W/E 08/15/20  \
# 0                                   0.0                                   0.0
# 1                                   0.3                                   0.3
# 2                                   0.0                                   0.0
# 3                                   NaN                                   NaN
# 4                                   0.1                                   0.1
#
#   Numerical Distribution 1 W/E 08/22/20 Numerical Distribution 1 W/E 08/29/20  \
# 0                                   0.0                                   0.0
# 1                                   0.4                                   0.4
# 2                                   0.0                                   0.0
# 3                                   NaN                                   NaN
# 4                                   0.1                                   0.1
#
#   Numerical Distribution 1 W/E 09/05/20 Numerical Distribution 1 W/E 09/12/20
# 0                                   0.0                                   0.0
# 1                                   0.2                                   0.5
# 2                                   0.0                                   0.0
# 3                                   NaN                                   NaN
# 4                                   0.1                                   0.1
#
# [5 rows x 574 columns]
